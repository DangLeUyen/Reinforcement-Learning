# %% [markdown]
# <a href="https://colab.research.google.com/github/DangLeUyen/Reinforcement-Learning/blob/main/U1_LunarLander.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install swig cmake
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 53 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 0s (8,103 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 122403 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install stable-baselines3==2.0.0a5
# !pip install swig
# !pip install gymnasium
# !pip install box2d-py
# !pip install huggingface_sb3
# Out:
# Collecting stable-baselines3==2.0.0a5
#   Using cached stable_baselines3-2.0.0a5-py3-none-any.whl.metadata (5.3 kB)
# Collecting gymnasium==0.28.1 (from stable-baselines3==2.0.0a5)
#   Using cached gymnasium-0.28.1-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0a5) (2.0.2)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0a5) (2.11.0+cu128)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0a5) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0a5) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3==2.0.0a5) (3.10.0)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->stable-baselines3==2.0.0a5)
#   Using cached jax_jumpy-1.0.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0a5) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0a5) (0.0.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.29.1)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->stable-baselines3==2.0.0a5) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->stable-baselines3==2.0.0a5) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->stable-baselines3==2.0.0a5) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->stable-baselines3==2.0.0a5) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->stable-baselines3==2.0.0a5) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->stable-baselines3==2.0.0a5) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->stable-baselines3==2.0.0a5) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->stable-baselines3==2.0.0a5) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->stable-baselines3==2.0.0a5) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->stable-baselines3==2.0.0a5) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->stable-baselines3==2.0.0a5) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.11->stable-baselines3==2.0.0a5) (12.8.90)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3==2.0.0a5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.0.0a5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3==2.0.0a5) (2026.2)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.11->stable-baselines3==2.0.0a5) (1.5.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0a5) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11->stable-baselines3==2.0.0a5) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11->stable-baselines3==2.0.0a5) (3.0.3)
# Downloading stable_baselines3-2.0.0a5-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.5/177.5 kB 7.6 MB/s eta 0:00:00
# Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 38.8 MB/s eta 0:00:00
# Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Installing collected packages: jax-jumpy, gymnasium, stable-baselines3
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.3.0
#     Uninstalling gymnasium-1.3.0:
#       Successfully uninstalled gymnasium-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.28.1 which is incompatible.
# Successfully installed gymnasium-0.28.1 jax-jumpy-1.0.0 stable-baselines3-2.0.0a5
# Collecting swig
#   Using cached swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 37.6 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.4.1
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (0.28.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.6)
# Collecting box2d-py
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp312-cp312-linux_x86_64.whl size=2398779 sha256=fe3d184fbf0ec75583c063ca7ccc565aac0f13823923aa2f55d2a6df5ad74b38
#   Stored in directory: /root/.cache/pip/wheels/d6/3c/ab/b6fd75459cadc56f4a4125d4cb387a708a59ca8589e4cc6b7d
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Collecting huggingface_sb3
#   Using cached huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting huggingface-hub~=0.8 (from huggingface_sb3)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (6.0.3)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (1.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.12/dist-packages (from huggingface_sb3) (3.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.29.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (1.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (26.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2026.5.20)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 13.6 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub, huggingface_sb3
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.17.0
#     Uninstalling huggingface_hub-1.17.0:
#       Successfully uninstalled huggingface_hub-1.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 5.10.1 requires huggingface-hub<2.0,>=1.5.0, but you have huggingface-hub 0.36.2 which is incompatible.
# Successfully installed huggingface-hub-0.36.2 huggingface_sb3-3.0

# %%
#  install virtual screen libraries and create and run a virtual screen
# !sudo apt-get update
# !sudo apt-get install -y python3-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [355 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,719 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,006 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,183 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,301 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,608 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,489 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,357 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.3 MB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,053 kB]
# Ign:19 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:20 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:21 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Ign:19 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:19 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Fetched 42.5 MB in 29s (1,442 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   freeglut3 libglu1-mesa
# Suggested packages:
#   libgle3 python3-numpy python3-tk
# The following NEW packages will be installed:
#   freeglut3 libglu1-mesa python3-opengl
# 0 upgraded, 3 newly installed, 0 to remove and 76 not upgraded.
# Need to get 824 kB of archives.
# After this operation, 8,092 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3 amd64 2.8.1-6 [74.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-opengl all 3.1.5+dfsg-1 [605 kB]
# Fetched 824 kB in 0s (2,645 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package freeglut3:amd64.
# (Reading database ... 123156 files and directories currently installed.)
# Preparing to unpack .../freeglut3_2.8.1-6_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-6) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package python3-opengl.
# Preparing to unpack .../python3-opengl_3.1.5+dfsg-1_all.deb ...
# Unpacking python3-opengl (3.1.5+dfsg-1) ...
# Setting up freeglut3:amd64 (2.8.1-6) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up python3-opengl (3.1.5+dfsg-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 76 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 76 not upgraded.
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
import os
os.kill(os.getpid(), 9)

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# Import the packages
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ### Create the LunarLander environment

# %%
import gymnasium as gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation, info = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  print("Action taken:", action)

  # Do this action in the environment and get
  # next_state, reward, terminated, truncated and info
  observation, reward, terminated, truncated, info = env.step(action)

  # If the game is terminated (in our case we land, crashed) or truncated (timeout)
  if terminated or truncated:
      # Reset the environment
      print("Environment is reset")
      observation, info = env.reset()

env.close()
# Out:
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# Action taken: 1
# Action taken: 1
# Action taken: 3
# Action taken: 2
# Action taken: 3
# Action taken: 3
# Action taken: 1
# Action taken: 1
# Action taken: 0
# Action taken: 3
# Action taken: 2
# Action taken: 3
# Action taken: 2
# Action taken: 0
# Action taken: 3
# Action taken: 3
# Action taken: 2
# Action taken: 2
# Action taken: 0
# Action taken: 1
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)

# %%
# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [44.67766    -6.5985847  -0.6868265   2.4690077  -1.1723568  -0.90062934
#   0.291103    0.84762543]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 3

# %% [markdown]
# Stable-Baselines3 is easy to set up:
#
# 1️⃣ You create your environment
#
# 2️⃣ You define the model you want to use and instantiate this model model = PPO("MlpPolicy")
#
# 3️⃣ You train the agent with model.learn and define the number of training timesteps

# %%
# Create the environment
env = make_vec_env('LunarLander-v2', n_envs=16)

# %% [markdown]
# ### Create the Model

# %%
# TODO: Define a PPO MlpPolicy architecture
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device

# %% [markdown]
# ### Traing the agent

# %%
# TODO: Train it for 1,000,000 timesteps
model.learn(total_timesteps=int(1000000))
# TODO: Specify file name for model and save the model to file
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.7     |
# |    ep_rew_mean     | -126     |
# | time/              |          |
# |    fps             | 2700     |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 106          |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 1906         |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.008458631  |
# |    clip_fraction        | 0.0728       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0034813285 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 415          |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.00599     |
# |    value_loss           | 1.09e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.2         |
# |    ep_rew_mean          | -98.2        |
# | time/                   |              |
# |    fps                  | 1798         |
# |    iterations           | 3            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0063320445 |
# |    clip_fraction        | 0.071        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.002941072  |
# |    learning_rate        | 0.0003       |
# |    loss                 | 414          |
# |    n_updates            | 16           |
# |    policy_gradient_loss | -0.00569     |
# |    value_loss           | 720          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | -92         |
# | time/                   |             |
# |    fps                  | 1708        |
# |    iterations           | 4           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009856991 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.03223145 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 271         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00494    |
# |    value_loss           | 669         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | -67.9       |
# | time/                   |             |
# |    fps                  | 1657        |
# |    iterations           | 5           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009798724 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.010131478 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 243         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00596    |
# |    value_loss           | 486         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 121          |
# |    ep_rew_mean          | -56.2        |
# | time/                   |              |
# |    fps                  | 1637         |
# |    iterations           | 6            |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.00991196   |
# |    clip_fraction        | 0.0716       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | -0.017702103 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 123          |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.0048      |
# |    value_loss           | 482          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 142          |
# |    ep_rew_mean          | -30.2        |
# | time/                   |              |
# |    fps                  | 1596         |
# |    iterations           | 7            |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.009215689  |
# |    clip_fraction        | 0.0695       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.002692461 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 130          |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.00535     |
# |    value_loss           | 357          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 160          |
# |    ep_rew_mean          | -24.6        |
# | time/                   |              |
# |    fps                  | 1555         |
# |    iterations           | 8            |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0051735267 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.0031952858 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 187          |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 398          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 185          |
# |    ep_rew_mean          | -23.6        |
# | time/                   |              |
# |    fps                  | 1500         |
# |    iterations           | 9            |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0075244037 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -0.026728868 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 289          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 540          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 211          |
# |    ep_rew_mean          | -19          |
# | time/                   |              |
# |    fps                  | 1367         |
# |    iterations           | 10           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0036252122 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | -0.003027916 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 283          |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.000448    |
# |    value_loss           | 600          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 277           |
# |    ep_rew_mean          | -5.69         |
# | time/                   |               |
# |    fps                  | 1275          |
# |    iterations           | 11            |
# |    time_elapsed         | 141           |
# |    total_timesteps      | 180224        |
# | train/                  |               |
# |    approx_kl            | 0.008012726   |
# |    clip_fraction        | 0.0583        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.21         |
# |    explained_variance   | 0.00027787685 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 203           |
# |    n_updates            | 48            |
# |    policy_gradient_loss | -0.000275     |
# |    value_loss           | 519           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | -4.37        |
# | time/                   |              |
# |    fps                  | 1191         |
# |    iterations           | 12           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.004084165  |
# |    clip_fraction        | 0.00455      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.0058339834 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 214          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 443          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 342          |
# |    ep_rew_mean          | -6.08        |
# | time/                   |              |
# |    fps                  | 1132         |
# |    iterations           | 13           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0037829063 |
# |    clip_fraction        | 0.00766      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.35074437   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 189          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 412          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 385         |
# |    ep_rew_mean          | 3.61        |
# | time/                   |             |
# |    fps                  | 1069        |
# |    iterations           | 14          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.005876366 |
# |    clip_fraction        | 0.0347      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.5705691   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 268         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00321    |
# |    value_loss           | 336         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 433          |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 1036         |
# |    iterations           | 15           |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0043427525 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.79170537   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 124          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 143          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 527         |
# |    ep_rew_mean          | 25.4        |
# | time/                   |             |
# |    fps                  | 988         |
# |    iterations           | 16          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.004372961 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.7335987   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 117         |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00283    |
# |    value_loss           | 275         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 591         |
# |    ep_rew_mean          | 22.1        |
# | time/                   |             |
# |    fps                  | 955         |
# |    iterations           | 17          |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.005229533 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.8142399   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 138         |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 150         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 667         |
# |    ep_rew_mean          | 25.7        |
# | time/                   |             |
# |    fps                  | 925         |
# |    iterations           | 18          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.004937961 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.7907896   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.9        |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00157    |
# |    value_loss           | 198         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 739          |
# |    ep_rew_mean          | 33.3         |
# | time/                   |              |
# |    fps                  | 898          |
# |    iterations           | 19           |
# |    time_elapsed         | 346          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0072129946 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.85324585   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.6         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 103          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 760          |
# |    ep_rew_mean          | 45.2         |
# | time/                   |              |
# |    fps                  | 874          |
# |    iterations           | 20           |
# |    time_elapsed         | 374          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0042465744 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.84581816   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 102          |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 127          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 795          |
# |    ep_rew_mean          | 55.8         |
# | time/                   |              |
# |    fps                  | 851          |
# |    iterations           | 21           |
# |    time_elapsed         | 403          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0045683756 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.93077624   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.3         |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 53.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 819          |
# |    ep_rew_mean          | 69.4         |
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 22           |
# |    time_elapsed         | 430          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0063724755 |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.9421489    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.1         |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 41.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 841         |
# |    ep_rew_mean          | 82.2        |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 23          |
# |    time_elapsed         | 458         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.006003186 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.9015844   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 95.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 848          |
# |    ep_rew_mean          | 90.4         |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 24           |
# |    time_elapsed         | 485          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0067575695 |
# |    clip_fraction        | 0.0698       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.9650017    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12           |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 30.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 847         |
# |    ep_rew_mean          | 93.7        |
# | time/                   |             |
# |    fps                  | 801         |
# |    iterations           | 25          |
# |    time_elapsed         | 510         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.003652343 |
# |    clip_fraction        | 0.0353      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.927935    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33          |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 78.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 887          |
# |    ep_rew_mean          | 100          |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 26           |
# |    time_elapsed         | 538          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0047333674 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.94676226   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.5         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.000852    |
# |    value_loss           | 57.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 891         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 782         |
# |    iterations           | 27          |
# |    time_elapsed         | 565         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.006541443 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.97935927  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.26        |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.00139    |
# |    value_loss           | 15.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 871          |
# |    ep_rew_mean          | 110          |
# | time/                   |              |
# |    fps                  | 778          |
# |    iterations           | 28           |
# |    time_elapsed         | 589          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0053444915 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.9462187    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.8         |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 63.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 860         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 29          |
# |    time_elapsed         | 614         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.005935618 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.9686972   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.54        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00166    |
# |    value_loss           | 35.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 899         |
# |    ep_rew_mean          | 120         |
# | time/                   |             |
# |    fps                  | 768         |
# |    iterations           | 30          |
# |    time_elapsed         | 639         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.008034953 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.9733235   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.9        |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.0011     |
# |    value_loss           | 32.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 892          |
# |    ep_rew_mean          | 123          |
# | time/                   |              |
# |    fps                  | 763          |
# |    iterations           | 31           |
# |    time_elapsed         | 665          |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0052656266 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.9815964    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.5          |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.000911    |
# |    value_loss           | 22.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 902         |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 32          |
# |    time_elapsed         | 691         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.010843653 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.9755448   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.06        |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.00166    |
# |    value_loss           | 32.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 926          |
# |    ep_rew_mean          | 128          |
# | time/                   |              |
# |    fps                  | 753          |
# |    iterations           | 33           |
# |    time_elapsed         | 717          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0046096975 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.9930767    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.87         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.000639    |
# |    value_loss           | 6.23         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 925         |
# |    ep_rew_mean          | 130         |
# | time/                   |             |
# |    fps                  | 749         |
# |    iterations           | 34          |
# |    time_elapsed         | 743         |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.003430009 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.9890702   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.35        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 5.47e-05    |
# |    value_loss           | 12.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 948          |
# |    ep_rew_mean          | 133          |
# | time/                   |              |
# |    fps                  | 747          |
# |    iterations           | 35           |
# |    time_elapsed         | 767          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0042468915 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.9783503    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.5          |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 21           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 955          |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 744          |
# |    iterations           | 36           |
# |    time_elapsed         | 792          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0047303042 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.977       |
# |    explained_variance   | 0.9955898    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 4.75         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 37          |
# |    time_elapsed         | 816         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.004544138 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | 0.9814924   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.76        |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -0.00015    |
# |    value_loss           | 26          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 38           |
# |    time_elapsed         | 838          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0041435575 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.995       |
# |    explained_variance   | 0.98637736   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.8         |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.000817    |
# |    value_loss           | 15.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 954         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 741         |
# |    iterations           | 39          |
# |    time_elapsed         | 861         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.004076494 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.945      |
# |    explained_variance   | 0.98947906  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.609       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00124    |
# |    value_loss           | 15.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 947         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 740         |
# |    iterations           | 40          |
# |    time_elapsed         | 885         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.004562122 |
# |    clip_fraction        | 0.0353      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.969      |
# |    explained_variance   | 0.9961346   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.37        |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.00166    |
# |    value_loss           | 4.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 931         |
# |    ep_rew_mean          | 141         |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 41          |
# |    time_elapsed         | 907         |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.007249704 |
# |    clip_fraction        | 0.0296      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.978      |
# |    explained_variance   | 0.9771344   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.6        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.00113    |
# |    value_loss           | 33.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 939         |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 42          |
# |    time_elapsed         | 930         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.003230716 |
# |    clip_fraction        | 0.0136      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.9718089   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.79        |
# |    n_updates            | 172         |
# |    policy_gradient_loss | -0.000793   |
# |    value_loss           | 37.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 148          |
# | time/                   |              |
# |    fps                  | 739          |
# |    iterations           | 43           |
# |    time_elapsed         | 952          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0048778867 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.936       |
# |    explained_variance   | 0.99393374   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.89         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | 0.000633     |
# |    value_loss           | 4.66         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 148          |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 44           |
# |    time_elapsed         | 976          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0051298346 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.92        |
# |    explained_variance   | 0.9974072    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.86         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -4.21e-05    |
# |    value_loss           | 2.61         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 151          |
# | time/                   |              |
# |    fps                  | 737          |
# |    iterations           | 45           |
# |    time_elapsed         | 999          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0052258503 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0.9976166    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.591        |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 2.6          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 969         |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 46          |
# |    time_elapsed         | 1023        |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.005652272 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.905      |
# |    explained_variance   | 0.9981559   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.8         |
# |    n_updates            | 188         |
# |    policy_gradient_loss | -0.000936   |
# |    value_loss           | 2.36        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 975          |
# |    ep_rew_mean          | 156          |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 47           |
# |    time_elapsed         | 1045         |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0052522575 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.87        |
# |    explained_variance   | 0.9898309    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.788        |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.000894    |
# |    value_loss           | 15.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 971          |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 48           |
# |    time_elapsed         | 1068         |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0028563817 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.85        |
# |    explained_variance   | 0.9727613    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.4         |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.000557    |
# |    value_loss           | 47.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 956          |
# |    ep_rew_mean          | 156          |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 49           |
# |    time_elapsed         | 1090         |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0036775463 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.808       |
# |    explained_variance   | 0.9731631    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.54         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 46.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 948          |
# |    ep_rew_mean          | 155          |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 50           |
# |    time_elapsed         | 1111         |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0032577447 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.816       |
# |    explained_variance   | 0.9833777    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.422        |
# |    n_updates            | 204          |
# |    policy_gradient_loss | 0.000932     |
# |    value_loss           | 22.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 932         |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 737         |
# |    iterations           | 51          |
# |    time_elapsed         | 1133        |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.003677708 |
# |    clip_fraction        | 0.0452      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.776      |
# |    explained_variance   | 0.98963636  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21        |
# |    n_updates            | 208         |
# |    policy_gradient_loss | -0.000251   |
# |    value_loss           | 7.72        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 913          |
# |    ep_rew_mean          | 153          |
# | time/                   |              |
# |    fps                  | 737          |
# |    iterations           | 52           |
# |    time_elapsed         | 1155         |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0035750829 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.817       |
# |    explained_variance   | 0.97326154   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.81         |
# |    n_updates            | 212          |
# |    policy_gradient_loss | -0.000575    |
# |    value_loss           | 37.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 891          |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 737          |
# |    iterations           | 53           |
# |    time_elapsed         | 1176         |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0062939404 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.766       |
# |    explained_variance   | 0.9436139    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 97.2         |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 97.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 851          |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 54           |
# |    time_elapsed         | 1198         |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0050286376 |
# |    clip_fraction        | 0.0538       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.745       |
# |    explained_variance   | 0.93702185   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.35         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000666    |
# |    value_loss           | 113          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 740        |
# |    ep_rew_mean          | 192        |
# | time/                   |            |
# |    fps                  | 739        |
# |    iterations           | 55         |
# |    time_elapsed         | 1218       |
# |    total_timesteps      | 901120     |
# | train/                  |            |
# |    approx_kl            | 0.00422291 |
# |    clip_fraction        | 0.0574     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.631     |
# |    explained_variance   | 0.88130283 |
# |    learning_rate        | 0.0003     |
# |    loss                 | 37.9       |
# |    n_updates            | 224        |
# |    policy_gradient_loss | -0.0028    |
# |    value_loss           | 230        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 559          |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 56           |
# |    time_elapsed         | 1235         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0047335736 |
# |    clip_fraction        | 0.0711       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.657       |
# |    explained_variance   | 0.8199302    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 186          |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 323          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 390         |
# |    ep_rew_mean          | 243         |
# | time/                   |             |
# |    fps                  | 746         |
# |    iterations           | 57          |
# |    time_elapsed         | 1250        |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.007214635 |
# |    clip_fraction        | 0.0907      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.721      |
# |    explained_variance   | 0.7024127   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.1        |
# |    n_updates            | 232         |
# |    policy_gradient_loss | -0.00389    |
# |    value_loss           | 326         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 327         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 58          |
# |    time_elapsed         | 1264        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.010144131 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.718      |
# |    explained_variance   | 0.6466847   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 236         |
# |    policy_gradient_loss | -0.00356    |
# |    value_loss           | 263         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 305          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 755          |
# |    iterations           | 59           |
# |    time_elapsed         | 1279         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0037912473 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.782       |
# |    explained_variance   | 0.7186149    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.6         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.000338     |
# |    value_loss           | 109          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 304          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 760          |
# |    iterations           | 60           |
# |    time_elapsed         | 1293         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0035381655 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.763       |
# |    explained_variance   | 0.48302996   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 210          |
# |    n_updates            | 244          |
# |    policy_gradient_loss | -0.000902    |
# |    value_loss           | 399          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 308          |
# |    ep_rew_mean          | 259          |
# | time/                   |              |
# |    fps                  | 764          |
# |    iterations           | 61           |
# |    time_elapsed         | 1308         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0038146162 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.755       |
# |    explained_variance   | 0.76612866   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.6         |
# |    n_updates            | 248          |
# |    policy_gradient_loss | -0.000374    |
# |    value_loss           | 97.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 301          |
# |    ep_rew_mean          | 258          |
# | time/                   |              |
# |    fps                  | 768          |
# |    iterations           | 62           |
# |    time_elapsed         | 1322         |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0024450948 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.759       |
# |    explained_variance   | 0.7110082    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.27         |
# |    n_updates            | 252          |
# |    policy_gradient_loss | -0.000234    |
# |    value_loss           | 164          |
# ------------------------------------------

# %% [markdown]
# ### Evaluate the agent

# %%
# Create a new environment for evaluation
eval_env = Monitor(gym.make("LunarLander-v2", render_mode='rgb_array'))

# Evaluate the model with 10 evaluation episodes and deterministic=True
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=263.88 +/- 22.033464842784944

# %%
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
import gymnasium as gym
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

## TODO: Define a repo_id
## repo_id is the id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
repo_id = "leuyendt/ppo-LunarLander-v2"

# TODO: Define the name of the environment
env_id = "LunarLander-v2"

# Create the evaluation env and set the render_mode="rgb_array"
eval_env = DummyVecEnv([lambda: Monitor(gym.make(env_id, render_mode="rgb_array"))])


# TODO: Define the model architecture we used
model_architecture = "ppo"

## TODO: Define the commit message
commit_message = "the first time I train RF model"

# method save, evaluate, generate a model card and record a replay video of your agent before pushing the repo to the hub
package_to_hub(model=model, # Our trained model
               model_name=model_name, # The name of our trained model
               model_architecture=model_architecture, # The model architecture we used: in our case PPO
               env_id=env_id, # Name of the environment
               eval_env=eval_env, # Evaluation Environment
               repo_id=repo_id, # id of the model repository from the Hugging Face Hub (repo_id = {organization}/{repo_name} for instance ThomasSimonini/ppo-LunarLander-v2
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Saving video to /tmp/tmpqfnwlfwr/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /tmp/tmpqfnwlfwr/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpqfnwlfwr/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpqfnwlfwr/-step-0-to-step-1000.mp4
# ℹ Pushing repo leuyendt/ppo-LunarLander-v2 to the Hugging Face Hub
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:114: DeprecationWarning: hf_xet.upload_files() is deprecated. Use XetSession().new_upload_commit().start_upload_file() instead.
#   return fn(*args, **kwargs)
#   ...-v2/pytorch_variables.pth: 100%|##########| 1.26kB / 1.26kB
#   ...LunarLander-v2/policy.pth: 100%|##########| 44.1kB / 44.1kB
#   ...ah/ppo-LunarLander-v2.zip: 100%|##########|  149kB /  149kB
#   /tmp/tmpmy_kh_ah/replay.mp4 : 100%|##########|  150kB /  150kB
#   ...r-v2/policy.optimizer.pth: 100%|##########| 88.7kB / 88.7kB
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/leuyendt/ppo-LunarLander-v2/tree/main/
# CommitInfo(commit_url='https://huggingface.co/leuyendt/ppo-LunarLander-v2/commit/f5429e74f608bff26a5f370598f60acc5d19532c', commit_message='the first time I train RF model', commit_description='', oid='f5429e74f608bff26a5f370598f60acc5d19532c', pr_url=None, repo_url=RepoUrl('https://huggingface.co/leuyendt/ppo-LunarLander-v2', endpoint='https://huggingface.co', repo_type='model', repo_id='leuyendt/ppo-LunarLander-v2'), pr_revision=None, pr_num=None)
